# %% [markdown]
# ## API Pull Code
# Author: Kate Meldrum (kmm4ap@virginia.edu)
#
# to request trial info from clinicaltrials.gov api and convert to pd dataframe

# %% [markdown]
# possible fields: https://clinicaltrials.gov/api/info/study_fields_list

# %% [markdown]
# DEMO CODE

# %%
import pandas as pd
import numpy as np
import requests
import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO
import time

# %%
# Field Definitions (change as desired)
min_rnk='1' #min pull rank
max_rnk='100' #max pull rank
fields='BriefTitle' #Fields to pull
fmt='csv' #Do not change for rest of code to work

# %%
#define url structure
api_url='https://clinicaltrials.gov/api/query/study_fields?%20&fields='+fields+'&min_rnk='+min_rnk+'&max_rnk='+max_rnk+'&fmt='+fmt
r = requests.get(api_url)

# %%
table=StringIO(str(r.text).split('\n\n')[1]) #delete API header and convert to string IO
table=pd.read_csv(table) # convert to pd dataframe

# %%
table
# Out:
#     Rank                                         BriefTitle
# 0      1  Role of Inhaler Adherence and Blood Eosinophil...
# 1      2                Validation orthèse Pour Gonarthrose
# 2      3  The Efficiency of Transcranial Direct Current ...
# 3      4  Muscle Strengthening and Return-to-exercise Cr...
# 4      5  Efficacy and Safety of High-dose L-AmB for Dis...
# ..   ...                                                ...
# 95    96    Semaglutide in Nonalcoholic Fatty Liver Disease
# 96    97  NOVOSYN® Quick Versus MONOSYN® Quick Suture Ma...
# 97    98  Effect of Gefapixant on Cough-related Brain Ac...
# 98    99  Myocardial Ischemia Detection With a Combined ...
# 99   100  Leaving Care - a Comparison Study of Implement...
#
# [100 rows x 2 columns]

# %% [markdown]
# FUNCTION

# %%
# As Function: 
def api_pull(min_rnk,max_rnk,fields):
    '''
    min_rnk: STR NUMBER newest trial to request (1 is newest in database)
    max_rnk: STR NUMBER oldest trial to request
    fields: STR fields to request separated by comma in single string
    '''
    #define url structure
    api_url='https://clinicaltrials.gov/api/query/study_fields?%20&fields='+fields+'&min_rnk='+min_rnk+'&max_rnk='+max_rnk+'&fmt=csv'
    r = requests.get(api_url) #request from api
    table=StringIO(str(r.text).split('\n\n')[1]) #delete API header and convert to string IO
    table=pd.read_csv(table) # convert to pd dataframe
    return table

# %%
api_pull('1','100','BriefTitle')
# Out:
#     Rank                                         BriefTitle
# 0      1  Role of Inhaler Adherence and Blood Eosinophil...
# 1      2                Validation orthèse Pour Gonarthrose
# 2      3  The Efficiency of Transcranial Direct Current ...
# 3      4  Muscle Strengthening and Return-to-exercise Cr...
# 4      5  Efficacy and Safety of High-dose L-AmB for Dis...
# ..   ...                                                ...
# 95    96    Semaglutide in Nonalcoholic Fatty Liver Disease
# 96    97  NOVOSYN® Quick Versus MONOSYN® Quick Suture Ma...
# 97    98  Effect of Gefapixant on Cough-related Brain Ac...
# 98    99  Myocardial Ischemia Detection With a Combined ...
# 99   100  Leaving Care - a Comparison Study of Implement...
#
# [100 rows x 2 columns]

# %% [markdown]
# GET DATA SET

# %%
def get_num_trials():
    '''
    Returns the number of trials currently availible from clinicaltrials.gov
    '''
    api_url='https://clinicaltrials.gov/api/query/study_fields?%20&fields=BriefTitle&min_rnk=1&max_rnk=10&fmt=csv'
    r = requests.get(api_url)
    return int(str(r.text).split('NStudiesAvail:')[1].split('"\n')[0])
get_num_trials()
# Out:
# 448686

# %% [markdown]
# SET UP NLP MODEL

# %%
# load in model
import spacy
nlp=spacy.load('/Users/meldrumapple/Desktop/Capstone/mod_chia_noscope/full_ent_list_mod/model-best')

# set up dict to store spans
label_list=['Person','Condition','Drug','Observation','Measurement','Procedure','Device','Visit','Negation','Qualifier','Temporal','Value','Multiplier','Reference_point','Mood','Post-eligibility','Pregnancy_considerations','Informed_consent']
ents_dict={}
for label in label_list:
    ents_dict[label]=[]
print(ents_dict)

# define funtion to get labels and spans for a text
def analyze(inc, exc):
    ents_col=[]
    spans_col=[]
    
    for (txt1, txt2) in zip(inc, exc):
        
        ents=[]
        spans=[]
        
        doc1=nlp(str(txt1))
        pred_ents1 = [(e.start_char, e.end_char, e.label_) for e in doc1.ents]
        for (start, end, label) in pred_ents1:
            ents.append(label)
            spans.append(txt1[start:end])
            ents_dict[label].append(txt1[start:end])
            
        if txt2 != None: 
            doc2=nlp(str(txt2))
            pred_ents2 = [(e.start_char, e.end_char, e.label_) for e in doc2.ents]
            for (start, end, label) in pred_ents2:
                ents.append(label)
                spans.append(txt2[start:end])
                ents_dict[label].append(txt2[start:end])
                
        ents_col.append(ents)
        spans_col.append(spans)
    return (ents_col, spans_col)
# Out:
# /Users/meldrumapple/anaconda3/envs/new/lib/python3.10/site-packages/spacy/util.py:877: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.5 and may not be 100% compatible with the current version (3.4.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# {'Person': [], 'Condition': [], 'Drug': [], 'Observation': [], 'Measurement': [], 'Procedure': [], 'Device': [], 'Visit': [], 'Negation': [], 'Qualifier': [], 'Temporal': [], 'Value': [], 'Multiplier': [], 'Reference_point': [], 'Mood': [], 'Post-eligibility': [], 'Pregnancy_considerations': [], 'Informed_consent': []}

# %%
# The pull didnt take that long so maybe we just want to get a new copy every time: 
def get_df():
    # define fields to pull:
    fields='NCTId,OfficialTitle,OrgFullName,CompletionDate,CompletionDateType,Condition,InterventionType,MinimumAge,MaximumAge,Gender,HealthyVolunteers,EligibilityCriteria'
    # define max rank to pull
    mx=get_num_trials()
    # divide into batches of 1000
    x=mx//1000
    # initialize dataframe
    df = pd.DataFrame(columns=['NCTId','OfficialTitle','OrgFullName','CompletionDate', 'CompletionDateType','Condition','InterventionType','MinimumAge','MaximumAge','Gender','HealthyVolunteers','InclusionCriteria','ExclusionCriteria','Entities','Spans'])
    
    #helper function to clean chunk
    def clean_chunk(chunk):
        # split eligibility into inclusion and exclusion
        chunk[['InclusionCriteria', 'ExclusionCriteria']]=chunk.EligibilityCriteria.str[21:].str.split("Exclusion Criteria:\\|\\|",expand=True).iloc[:,:2]
        # drop cols we don't want
        chunk=chunk.drop(['EligibilityCriteria', 'Rank'], axis=1)
        # perform nlp analysis and store
        chunk_nlp=analyze(chunk['InclusionCriteria'], chunk['ExclusionCriteria'])
        chunk['Entities']=chunk_nlp[0]
        chunk['Spans']=chunk_nlp[1]
        return chunk
        

    for i in range(0, x):
        
        # define ranks to pull
        min_rnk=str((i*1000)+1)
        max_rnk=str((i+1)*1000)
        print(min_rnk, max_rnk)
        
        # pull ranks 
        chunk=api_pull(min_rnk,max_rnk,fields) 
        chunk=clean_chunk(chunk)
    
        # add to big dataframe
        df=pd.concat([df, chunk], axis=0)
    # get new trials from remainder
    chunk=api_pull(str((x*1000)+1), str(mx), fields)
    chunk=clean_chunk(chunk)
    df=pd.concat([df,chunk], axis=0)
    return df

# %%
st=time.time()
data_set=get_df()
et=time.time()
print(et-st)
# Out:
# 1 1000
# 1001 2000
# 2001 3000
# 3001 4000
# 4001 5000
# 5001 6000
# 6001 7000
# 7001 8000
# 8001 9000
# 9001 10000
# 10001 11000
# 11001 12000
# 12001 13000
# 13001 14000
# 14001 15000
# 15001 16000
# 16001 17000
# 17001 18000
# 18001 19000
# 19001 20000
# 20001 21000
# 21001 22000
# 22001 23000
# 23001 24000
# 24001 25000
# 25001 26000
# 26001 27000
# 27001 28000
# 28001 29000
# 29001 30000
# 30001 31000
# 31001 32000
# 32001 33000
# 33001 34000
# 34001 35000
# 35001 36000
# 36001 37000
# 37001 38000
# 38001 39000
# 39001 40000
# 40001 41000
# 41001 42000
# 42001 43000
# 43001 44000
# 44001 45000
# 45001 46000
# 46001 47000
# 47001 48000
# 48001 49000
# 49001 50000
# 50001 51000
# 51001 52000
# 52001 53000
# 53001 54000
# 54001 55000
# 55001 56000
# 56001 57000
# 57001 58000
# 58001 59000
# 59001 60000
# 60001 61000
# 61001 62000
# 62001 63000
# 63001 64000
# 64001 65000
# 65001 66000
# 66001 67000
# 67001 68000
# 68001 69000
# 69001 70000
# 70001 71000
# 71001 72000
# 72001 73000
# 73001 74000
# 74001 75000
# 75001 76000
# 76001 77000
# 77001 78000
# 78001 79000
# 79001 80000
# 80001 81000
# 81001 82000
# 82001 83000
# 83001 84000
# 84001 85000
# 85001 86000
# 86001 87000
# 87001 88000
# 88001 89000
# 89001 90000
# 90001 91000
# 91001 92000
# 92001 93000
# 93001 94000
# 94001 95000
# 95001 96000
# 96001 97000
# 97001 98000
# 98001 99000
# 99001 100000
# 100001 101000
# 101001 102000
# 102001 103000
# 103001 104000
# 104001 105000
# 105001 106000
# 106001 107000
# 107001 108000
# 108001 109000
# 109001 110000
# 110001 111000
# 111001 112000
# 112001 113000
# 113001 114000
# 114001 115000
# 115001 116000
# 116001 117000
# 117001 118000
# 118001 119000
# 119001 120000
# 120001 121000
# 121001 122000
# 122001 123000
# 123001 124000
# 124001 125000
# 125001 126000
# 126001 127000
# 127001 128000
# 128001 129000
# 129001 130000
# 130001 131000
# 131001 132000
# 132001 133000
# 133001 134000
# 134001 135000
# 135001 136000
# 136001 137000
# 137001 138000
# 138001 139000
# 139001 140000
# 140001 141000
# 141001 142000
# 142001 143000
# 143001 144000
# 144001 145000
# 145001 146000
# 146001 147000
# 147001 148000
# 148001 149000
# 149001 150000
# 150001 151000
# 151001 152000
# 152001 153000
# 153001 154000
# 154001 155000
# 155001 156000
# 156001 157000
# 157001 158000
# 158001 159000
# 159001 160000
# 160001 161000
# 161001 162000
# 162001 163000
# 163001 164000
# 164001 165000
# 165001 166000
# 166001 167000
# 167001 168000
# 168001 169000
# 169001 170000
# 170001 171000
# 171001 172000
# 172001 173000
# 173001 174000
# 174001 175000
# 175001 176000
# 176001 177000
# 177001 178000
# 178001 179000
# 179001 180000
# 180001 181000
# 181001 182000
# 182001 183000
# 183001 184000
# 184001 185000
# 185001 186000
# 186001 187000
# 187001 188000
# 188001 189000
# 189001 190000
# 190001 191000
# 191001 192000
# 192001 193000
# 193001 194000
# 194001 195000
# 195001 196000
# 196001 197000
# 197001 198000
# 198001 199000
# 199001 200000
# 200001 201000
# 201001 202000
# 202001 203000
# 203001 204000
# 204001 205000
# 205001 206000
# 206001 207000
# 207001 208000
# 208001 209000
# 209001 210000
# 210001 211000
# 211001 212000
# 212001 213000
# 213001 214000
# 214001 215000
# 215001 216000
# 216001 217000
# 217001 218000
# 218001 219000
# 219001 220000
# 220001 221000
# 221001 222000
# 222001 223000
# 223001 224000
# 224001 225000
# 225001 226000
# 226001 227000
# 227001 228000
# 228001 229000
# 229001 230000
# 230001 231000
# 231001 232000
# 232001 233000
# 233001 234000
# 234001 235000
# 235001 236000
# 236001 237000
# 237001 238000
# 238001 239000
# 239001 240000
# 240001 241000
# 241001 242000
# 242001 243000
# 243001 244000
# 244001 245000
# 245001 246000
# 246001 247000
# 247001 248000
# 248001 249000
# 249001 250000
# 250001 251000
# 251001 252000
# 252001 253000
# 253001 254000
# 254001 255000
# 255001 256000
# 256001 257000
# 257001 258000
# 258001 259000
# 259001 260000
# 260001 261000
# 261001 262000
# 262001 263000
# 263001 264000
# 264001 265000
# 265001 266000
# 266001 267000
# 267001 268000
# 268001 269000
# 269001 270000
# 270001 271000
# 271001 272000
# 272001 273000
# 273001 274000
# 274001 275000
# 275001 276000
# 276001 277000
# 277001 278000
# 278001 279000
# 279001 280000
# 280001 281000
# 281001 282000
# 282001 283000
# 283001 284000
# 284001 285000
# 285001 286000
# 286001 287000
# 287001 288000
# 288001 289000
# 289001 290000
# 290001 291000
# 291001 292000
# 292001 293000
# 293001 294000
# 294001 295000
# 295001 296000
# 296001 297000
# 297001 298000
# 298001 299000
# 299001 300000
# 300001 301000
# 301001 302000
# 302001 303000
# 303001 304000
# 304001 305000
# 305001 306000
# 306001 307000
# 307001 308000
# 308001 309000
# 309001 310000
# 310001 311000
# 311001 312000
# 312001 313000
# 313001 314000
# 314001 315000
# 315001 316000
# 316001 317000
# 317001 318000
# 318001 319000
# 319001 320000
# 320001 321000
# 321001 322000
# 322001 323000
# 323001 324000
# 324001 325000
# 325001 326000
# 326001 327000
# 327001 328000
# 328001 329000
# 329001 330000
# 330001 331000
# 331001 332000
# 332001 333000
# 333001 334000
# 334001 335000
# 335001 336000
# 336001 337000
# 337001 338000
# 338001 339000
# 339001 340000
# 340001 341000
# 341001 342000
# 342001 343000
# 343001 344000
# 344001 345000
# 345001 346000
# 346001 347000
# 347001 348000
# 348001 349000
# 349001 350000
# 350001 351000
# 351001 352000
# 352001 353000
# 353001 354000
# 354001 355000
# 355001 356000
# 356001 357000
# 357001 358000
# 358001 359000
# 359001 360000
# 360001 361000
# 361001 362000
# 362001 363000
# 363001 364000
# 364001 365000
# 365001 366000
# 366001 367000
# 367001 368000
# 368001 369000
# 369001 370000
# 370001 371000
# 371001 372000
# 372001 373000
# 373001 374000
# 374001 375000
# 375001 376000
# 376001 377000
# 377001 378000
# 378001 379000
# 379001 380000
# 380001 381000
# 381001 382000
# 382001 383000
# 383001 384000
# 384001 385000
# 385001 386000
# 386001 387000
# 387001 388000
# 388001 389000
# 389001 390000
# 390001 391000
# 391001 392000
# 392001 393000
# 393001 394000
# 394001 395000
# 395001 396000
# 396001 397000
# 397001 398000
# 398001 399000
# 399001 400000
# 400001 401000
# 401001 402000
# 402001 403000
# 403001 404000
# 404001 405000
# 405001 406000
# 406001 407000
# 407001 408000
# 408001 409000
# 409001 410000
# 410001 411000
# 411001 412000
# 412001 413000
# 413001 414000
# 414001 415000
# 415001 416000
# 416001 417000
# 417001 418000
# 418001 419000
# 419001 420000
# 420001 421000
# 421001 422000
# 422001 423000
# 423001 424000
# 424001 425000
# 425001 426000
# 426001 427000
# 427001 428000
# 428001 429000
# 429001 430000
# 430001 431000
# 431001 432000
# 432001 433000
# 433001 434000
# 434001 435000
# 435001 436000
# 436001 437000
# 437001 438000
# 438001 439000
# 439001 440000
# 440001 441000
# 441001 442000
# 442001 443000
# 443001 444000
# 444001 445000
# 445001 446000
# 446001 447000
# 447001 448000
# 7916.425459861755

# %%
len(data_set)
# Out:
# 448686

# %%
get_num_trials()
# Out:
# 448686

# %%
data_set.to_csv('/Users/meldrumapple/Desktop/Capstone/api_pull_data.csv')

# %%
len(pd.read_csv('/Users/meldrumapple/Desktop/Capstone/api_pull_data.csv'))
# Out:
# 448686

# %%
set_ents_dict={}
for x in ents_dict.keys():
    set_ents_dict[x]=[list(set(ents_dict[x]))]
ents_df=pd.DataFrame(set_ents_dict)
ents_df.to_csv('/Users/meldrumapple/Desktop/Capstone/ents_spans.csv')
